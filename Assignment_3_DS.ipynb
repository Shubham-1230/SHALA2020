# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham-1230/SHALA2020/blob/master/DS_L3_20_April_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment - 3: Improving Graphs**
#
# ---
# Course website: [SHALA-2020](https://shala2020.github.io/)
#
# This assignment will get you familiarized with improving plots/graphs in Python.

# %% [markdown]
# ---
# ## Part 1 - Importing packages and loading data
# ---

# %% [markdown]
# ###Import the following libraries:
#
# * ```numpy``` with an alias name ```np```,
# * ```pandas``` with an alias name ```pd```,
# * ```matplotlib.pyplot``` with an alias name ```plt```, and
# * ```seaborn``` with an alias name ```sns```.
#
# *You are free to use any other popular libraries*.

# %%
# Load the libraries with their aliases 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Using the files ```train.csv``` and ```moviesData.csv```,  peform the following:
#
# * Load these file as ```pandas``` dataframes and store it in variables named ```train``` and ```movies``` respectively.
# * Print the first ten rows of ```train``` and last ten rows of ```movies```.

# %%
# Load train.csv and movies.csv 
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv(url_train)

# Print the first ten rows of train
train.head(10)
# Out:
#    Age  Attrition  ... YearsWithCurrManager  ID
# 0   41          1  ...                    5   0
# 1   49          0  ...                    7   1
# 2   37          1  ...                    0   2
# 3   33          0  ...                    0   3
# 4   27          0  ...                    2   4
# 5   32          0  ...                    6   5
# 6   59          0  ...                    0   6
# 7   30          0  ...                    0   7
# 8   38          0  ...                    8   8
# 9   36          0  ...                    7   9
#
# [10 rows x 34 columns]

# %%
# Load movies.csv
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url_movies)

# Print the last ten rows of movies 
movies[-10:]
# Out:
#      Unnamed: 0  ...            actor5
# 590         591  ...        Ben Vereen
# 591         592  ...       Bob Balaban
# 592         593  ...     George Gaynes
# 593         594  ...   Lance Henriksen
# 594         595  ...  Steve Guttenberg
# 595         596  ...       Jack Bailey
# 596         597  ...       Rachel True
# 597         598  ...    Randy McDowell
# 598         599  ...       Ian McNeice
# 599         600  ...    Adam G. Sevani
#
# [10 rows x 31 columns]

# %% [markdown]
# ---
# ## Part 2 - Drawing correlation and heatmap
# ---

# %% [markdown]
# ### Using the correlation matrix, peform the following:
#
# * Find the correlation matrix for the ```movies```.
# * Draw a **heatmap** with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.
# * Create a ```mask``` to remove the duplicate values from the **heatmap**.

# %%
# Find out the correlation matrix 
movies.corr()
# Draw the heatmap
plt.figure(figsize=(20,10))
sns.heatmap(movies.corr())

# %%
# Creating a mask for removing duplicates 
plt.figure(figsize=(20,10))
mask = np.zeros_like(movies.corr())
mask[np.triu_indices_from(mask)]=True
sns.heatmap(movies.corr(),vmin=-1,vmax=1,cmap='coolwarm',annot=True,mask=mask)

# %% [markdown]
# ---
# ## Part 3 - Drawing plots and customizing these
# ---

# %% [markdown]
# ### Using a histogram, peform the following:
#
# * Draw a histogram of all the numeric features in ```train```. Please note that this can be done in a single command.
#
# * Find out whether there is any redundant features in ```train```, which can be dropped while building a model.

# %%
# Draw a histogram
train.hist(figsize=(25,25),bins=25)
# Find out the redundant features
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fe54dcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fe1ea828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fe199ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fe14af28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fe1082e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fe0b9668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fe0ec9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fe09cd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fe09cda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fe00f4a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdfc1828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdf73ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdfa7f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdf652e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdf16668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdec89e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fde79d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fde3b128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fde6d4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fde1e828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fddd0ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdd81f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdd3e2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdcf3668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdd249e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdcd9d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdc97128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdc4a4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdbfc828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6fdc2eba8>]],
#       dtype=object)

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Draw a scatter plot between between ```imdb_rating``` and ```audience_score```, and also fit a regression line.
# * Change the color of marker to red, size to 200, transparency to 0.3.

# %%
# Scatter plot to fit the regression line 
sns.regplot('imdb_rating', 'audience_score', data=movies, ci=95)

# %%
# Change marker of the scatter plot
sns.regplot('imdb_rating', 'audience_score', data=movies, ci=95, scatter_kws={'color':'r','alpha':0.3,'s':200})

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw a scatter plot between between ```petal_length``` and ```petal_width``` and color it according to the ```species```.
# * Change the size of marker to 100 and place the legend in ```lower right```.

# %%
# library & dataset
# import seaborn as sns
df = sns.load_dataset('iris')
# df.head
# Use the 'hue' argument to provide a factor variable
sns.lmplot('petal_length', 'petal_width', data=df, hue='species', fit_reg=False, legend=False, scatter_kws={'s':100})
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %% [markdown]
# ---
# ## Part 4 - Density Plots
# ---

# %% [markdown]
# ### Using density plots, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots for all the features ```sepal_width```, ```sepal_length```, ```petal_width```, and ```petal_length```. You can required to use subplots for plotting all the density plots.
# * Try drawing a [CDF](https://en.wikipedia.org/wiki/Cumulative_distribution_function) of these features. There is a [blog on medium](https://medium.com/@rishav.jnit/exploratory-data-analysis-eda-on-iris-dataset-using-python-cadd850c1fc6) on how to plot CDF. It will be covered in tutorial.

# %%
# library and dataset
from pylab import*
# df = sns.load_dataset('iris')
subplot(2,2,1)
sns.distplot(df.sepal_width,color='r')
subplot(2,2,2)
sns.distplot(df.sepal_length,color='g')
subplot(2,2,3)
sns.distplot(df.petal_width,color='b')
subplot(2,2,4)
sns.distplot(df.petal_length,color='y')

# %%
from pylab import*
# df = sns.load_dataset('iris')
subplot(2,2,1)
sns.kdeplot(df.sepal_width,shade=True,cumulative=True,color='r')
subplot(2,2,2)
sns.kdeplot(df.sepal_length,shade=True,cumulative=True,color='g')
subplot(2,2,3)
sns.kdeplot(df.petal_width,shade=True,cumulative=True,color='b')
subplot(2,2,4)
sns.kdeplot(df.petal_length,shade=True,cumulative=True,color='y')

# %%
# Draw the normal violin plots 
sns.violinplot(x='species',y='sepal_length',data=df,palette='Blues')

# %% [markdown]
# ### Using violin plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots of ```species``` versus ```sepal_length```.
# * Assign each group a color like
#
#     * versicolor - green,
#     * setosa - blue,
#     * virginica - m

# %%
# Change the color of each group 
sns.violinplot(x='species',y='sepal_length',data=df,palette={'setosa':'b','versicolor':'g','virginica':'m'})
